# %% [markdown]
# <a href="https://colab.research.google.com/github/Sipten-raza/Deep-Learning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-dsxrn_7f
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-dsxrn_7f
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=3e4f2b18f9ee6314b7ddd2f3e16bbbb3a5c321b3e02b7f7e2c71af97ef938a4e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rubvkcsb/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303503, train error 89.70,  test loss 2.304685, test error 90.12
# Epoch   100, train loss 1.913255, train error 71.32,  test loss 1.748604, test error 68.60
# Epoch   200, train loss 1.883117, train error 70.57,  test loss 1.707719, test error 67.97
# Epoch   300, train loss 1.847828, train error 70.50,  test loss 1.686708, test error 66.75
# Epoch   400, train loss 1.841198, train error 69.32,  test loss 1.696416, test error 67.40
# Epoch   500, train loss 1.838372, train error 68.30,  test loss 1.685742, test error 66.90
# Epoch   600, train loss 1.846710, train error 69.22,  test loss 1.675727, test error 67.05
# Epoch   700, train loss 1.846859, train error 70.12,  test loss 1.682858, test error 67.62
# Epoch   800, train loss 1.833737, train error 68.88,  test loss 1.650069, test error 66.25
# Epoch   900, train loss 1.830426, train error 68.62,  test loss 1.656794, test error 65.75
# Training model with   4 hidden variables
# Epoch     0, train loss 2.277676, train error 84.03,  test loss 2.285014, test error 82.82
# Epoch   100, train loss 1.753329, train error 64.43,  test loss 1.589286, test error 62.62
# Epoch   200, train loss 1.728221, train error 63.17,  test loss 1.587231, test error 61.85
# Epoch   300, train loss 1.717746, train error 62.78,  test loss 1.585312, test error 61.90
# Epoch   400, train loss 1.724257, train error 63.90,  test loss 1.578052, test error 62.90
# Epoch   500, train loss 1.709417, train error 62.50,  test loss 1.580770, test error 61.45
# Epoch   600, train loss 1.706957, train error 62.25,  test loss 1.581080, test error 60.90
# Epoch   700, train loss 1.705444, train error 62.20,  test loss 1.578982, test error 61.60
# Epoch   800, train loss 1.701656, train error 61.75,  test loss 1.571748, test error 61.65
# Epoch   900, train loss 1.699548, train error 62.05,  test loss 1.571354, test error 60.60
# Training model with   6 hidden variables
# Epoch     0, train loss 2.249773, train error 84.10,  test loss 2.237982, test error 83.90
# Epoch   100, train loss 1.806766, train error 65.45,  test loss 1.652790, test error 64.88
# Epoch   200, train loss 1.651209, train error 59.22,  test loss 1.458895, test error 57.58
# Epoch   300, train loss 1.629849, train error 57.83,  test loss 1.468108, test error 58.50
# Epoch   400, train loss 1.621777, train error 58.60,  test loss 1.469821, test error 58.30
# Epoch   500, train loss 1.613749, train error 58.40,  test loss 1.462672, test error 57.50
# Epoch   600, train loss 1.594336, train error 57.62,  test loss 1.439346, test error 56.28
# Epoch   700, train loss 1.601147, train error 57.60,  test loss 1.445921, test error 56.38
# Epoch   800, train loss 1.589163, train error 57.60,  test loss 1.440210, test error 56.50
# Epoch   900, train loss 1.591391, train error 57.58,  test loss 1.455688, test error 56.40
# Training model with   8 hidden variables
# Epoch     0, train loss 2.272419, train error 85.93,  test loss 2.264729, test error 85.68
# Epoch   100, train loss 1.630018, train error 58.00,  test loss 1.441886, test error 56.70
# Epoch   200, train loss 1.573398, train error 55.42,  test loss 1.404535, test error 54.12
# Epoch   300, train loss 1.557324, train error 53.97,  test loss 1.408875, test error 54.22
# Epoch   400, train loss 1.537691, train error 54.08,  test loss 1.398390, test error 53.50
# Epoch   500, train loss 1.504925, train error 51.08,  test loss 1.357979, test error 51.83
# Epoch   600, train loss 1.477307, train error 50.08,  test loss 1.339595, test error 50.40
# Epoch   700, train loss 1.470172, train error 49.90,  test loss 1.340802, test error 50.78
# Epoch   800, train loss 1.464774, train error 49.67,  test loss 1.343303, test error 50.33
# Epoch   900, train loss 1.464574, train error 49.65,  test loss 1.336273, test error 50.38
# Training model with  10 hidden variables
# Epoch     0, train loss 2.159451, train error 81.75,  test loss 2.124518, test error 81.47
# Epoch   100, train loss 1.569814, train error 55.05,  test loss 1.441326, test error 55.95
# Epoch   200, train loss 1.523027, train error 52.03,  test loss 1.436876, test error 55.55
# Epoch   300, train loss 1.497974, train error 52.28,  test loss 1.432111, test error 53.92
# Epoch   400, train loss 1.477630, train error 51.62,  test loss 1.427730, test error 54.47
# Epoch   500, train loss 1.465586, train error 50.90,  test loss 1.445874, test error 55.20
# Epoch   600, train loss 1.457589, train error 50.85,  test loss 1.444185, test error 54.45
# Epoch   700, train loss 1.451727, train error 50.60,  test loss 1.451723, test error 55.12
# Epoch   800, train loss 1.442738, train error 50.60,  test loss 1.465379, test error 55.80
# Epoch   900, train loss 1.438179, train error 50.53,  test loss 1.485970, test error 56.65
# Training model with  14 hidden variables
# Epoch     0, train loss 2.213242, train error 83.28,  test loss 2.197534, test error 83.20
# Epoch   100, train loss 1.512884, train error 52.62,  test loss 1.448798, test error 56.42
# Epoch   200, train loss 1.399123, train error 48.75,  test loss 1.401264, test error 52.83
# Epoch   300, train loss 1.346735, train error 46.53,  test loss 1.399191, test error 51.62
# Epoch   400, train loss 1.322136, train error 45.90,  test loss 1.413751, test error 52.03
# Epoch   500, train loss 1.314046, train error 45.58,  test loss 1.423396, test error 51.85
# Epoch   600, train loss 1.310123, train error 45.12,  test loss 1.441977, test error 52.03
# Epoch   700, train loss 1.295691, train error 44.33,  test loss 1.449860, test error 52.83
# Epoch   800, train loss 1.299739, train error 44.78,  test loss 1.466873, test error 52.55
# Epoch   900, train loss 1.294727, train error 44.60,  test loss 1.477977, test error 52.28
# Training model with  18 hidden variables
# Epoch     0, train loss 2.227656, train error 81.72,  test loss 2.211051, test error 81.15
# Epoch   100, train loss 1.350206, train error 45.15,  test loss 1.327217, test error 49.35
# Epoch   200, train loss 1.258691, train error 42.15,  test loss 1.340335, test error 49.03
# Epoch   300, train loss 1.211786, train error 41.38,  test loss 1.370391, test error 49.72
# Epoch   400, train loss 1.193356, train error 40.10,  test loss 1.407126, test error 49.42
# Epoch   500, train loss 1.173006, train error 39.47,  test loss 1.419448, test error 50.03
# Epoch   600, train loss 1.161620, train error 39.38,  test loss 1.445453, test error 50.25
# Epoch   700, train loss 1.151600, train error 39.40,  test loss 1.472009, test error 51.12
# Epoch   800, train loss 1.136155, train error 37.83,  test loss 1.492382, test error 51.17
# Epoch   900, train loss 1.127195, train error 38.17,  test loss 1.525956, test error 51.97
# Training model with  22 hidden variables
# Epoch     0, train loss 2.101548, train error 79.25,  test loss 2.050772, test error 78.25
# Epoch   100, train loss 1.296785, train error 44.10,  test loss 1.316292, test error 48.88
# Epoch   200, train loss 1.165208, train error 39.75,  test loss 1.349703, test error 47.85
# Epoch   300, train loss 1.104756, train error 37.08,  test loss 1.423716, test error 49.80
# Epoch   400, train loss 1.065654, train error 36.33,  test loss 1.490574, test error 49.97
# Epoch   500, train loss 1.043102, train error 35.97,  test loss 1.554451, test error 50.47
# Epoch   600, train loss 1.025554, train error 35.20,  test loss 1.634350, test error 51.83
# Epoch   700, train loss 1.007870, train error 35.03,  test loss 1.678752, test error 52.62
# Epoch   800, train loss 0.983160, train error 34.50,  test loss 1.719927, test error 52.60
# Epoch   900, train loss 0.980602, train error 34.03,  test loss 1.788593, test error 53.40
# Training model with  26 hidden variables
# Epoch     0, train loss 2.210409, train error 81.43,  test loss 2.197597, test error 80.95
# Epoch   100, train loss 1.173906, train error 38.85,  test loss 1.355232, test error 48.38
# Epoch   200, train loss 1.048760, train error 34.65,  test loss 1.493259, test error 50.75
# Epoch   300, train loss 0.970277, train error 32.03,  test loss 1.618632, test error 53.12
# Epoch   400, train loss 0.920342, train error 30.90,  test loss 1.715370, test error 53.30
# Epoch   500, train loss 0.896543, train error 29.97,  test loss 1.814179, test error 53.60
# Epoch   600, train loss 0.873938, train error 29.22,  test loss 1.889728, test error 54.45
# Epoch   700, train loss 0.868495, train error 29.53,  test loss 1.964195, test error 54.95
# Epoch   800, train loss 0.835093, train error 27.93,  test loss 2.030652, test error 55.15
# Epoch   900, train loss 0.829406, train error 27.90,  test loss 2.086292, test error 54.83
# Training model with  30 hidden variables
# Epoch     0, train loss 2.143674, train error 80.07,  test loss 2.094971, test error 78.40
# Epoch   100, train loss 1.076550, train error 35.60,  test loss 1.378015, test error 49.08
# Epoch   200, train loss 0.913963, train error 30.00,  test loss 1.552807, test error 50.38
# Epoch   300, train loss 0.829454, train error 27.45,  test loss 1.740549, test error 51.40
# Epoch   400, train loss 0.782329, train error 26.43,  test loss 1.876099, test error 52.20
# Epoch   500, train loss 0.757888, train error 26.28,  test loss 2.066303, test error 53.75
# Epoch   600, train loss 0.728674, train error 24.85,  test loss 2.184669, test error 54.25
# Epoch   700, train loss 0.714075, train error 24.75,  test loss 2.240492, test error 54.28
# Epoch   800, train loss 0.694427, train error 24.60,  test loss 2.352803, test error 54.40
# Epoch   900, train loss 0.681987, train error 24.03,  test loss 2.474325, test error 55.33
# Training model with  35 hidden variables
# Epoch     0, train loss 2.200454, train error 80.30,  test loss 2.160910, test error 79.95
# Epoch   100, train loss 1.045161, train error 34.12,  test loss 1.402333, test error 50.58
# Epoch   200, train loss 0.831584, train error 27.12,  test loss 1.681466, test error 52.80
# Epoch   300, train loss 0.681550, train error 21.62,  test loss 1.994864, test error 54.72
# Epoch   400, train loss 0.597920, train error 19.68,  test loss 2.336251, test error 54.60
# Epoch   500, train loss 0.536800, train error 17.62,  test loss 2.658008, test error 55.35
# Epoch   600, train loss 0.527349, train error 17.38,  test loss 3.017233, test error 56.80
# Epoch   700, train loss 0.489431, train error 16.40,  test loss 3.266638, test error 56.83
# Epoch   800, train loss 0.452001, train error 14.95,  test loss 3.483754, test error 57.10
# Epoch   900, train loss 0.441286, train error 14.47,  test loss 3.713589, test error 57.40
# Training model with  40 hidden variables
# Epoch     0, train loss 2.069544, train error 77.57,  test loss 2.013918, test error 76.30
# Epoch   100, train loss 0.943465, train error 30.20,  test loss 1.450370, test error 51.05
# Epoch   200, train loss 0.653610, train error 20.95,  test loss 1.999767, test error 53.45
# Epoch   300, train loss 0.489807, train error 15.60,  test loss 2.725622, test error 56.00
# Epoch   400, train loss 0.417165, train error 14.65,  test loss 3.559167, test error 57.15
# Epoch   500, train loss 0.383636, train error 13.53,  test loss 4.269894, test error 57.55
# Epoch   600, train loss 0.308937, train error 11.00,  test loss 4.937335, test error 57.72
# Epoch   700, train loss 0.345436, train error 11.90,  test loss 5.635747, test error 58.88
# Epoch   800, train loss 0.330081, train error 11.80,  test loss 6.336350, test error 58.45
# Epoch   900, train loss 0.313367, train error 11.28,  test loss 6.894015, test error 57.88
# Training model with  45 hidden variables
# Epoch     0, train loss 2.128053, train error 79.20,  test loss 2.090739, test error 79.15
# Epoch   100, train loss 0.805423, train error 25.03,  test loss 1.469279, test error 48.90
# Epoch   200, train loss 0.472792, train error 15.30,  test loss 2.238084, test error 53.30
# Epoch   300, train loss 0.293404, train error 9.00,  test loss 3.278498, test error 55.10
# Epoch   400, train loss 0.162629, train error 4.55,  test loss 4.426862, test error 55.80
# Epoch   500, train loss 0.151050, train error 4.93,  test loss 5.660885, test error 55.80
# Epoch   600, train loss 0.018961, train error 0.00,  test loss 6.915656, test error 55.78
# Epoch   700, train loss 0.011042, train error 0.00,  test loss 7.689604, test error 55.97
# Epoch   800, train loss 0.007726, train error 0.00,  test loss 8.252970, test error 55.92
# Epoch   900, train loss 0.005950, train error 0.00,  test loss 8.692518, test error 56.15
# Training model with  50 hidden variables
# Epoch     0, train loss 2.080942, train error 77.70,  test loss 2.039262, test error 77.32
# Epoch   100, train loss 0.725209, train error 23.32,  test loss 1.651995, test error 51.55
# Epoch   200, train loss 0.323149, train error 8.53,  test loss 2.678027, test error 53.62
# Epoch   300, train loss 0.168235, train error 4.30,  test loss 4.275303, test error 55.47
# Epoch   400, train loss 0.026369, train error 0.00,  test loss 5.942507, test error 56.08
# Epoch   500, train loss 0.012578, train error 0.00,  test loss 6.916892, test error 56.03
# Epoch   600, train loss 0.007937, train error 0.00,  test loss 7.539585, test error 55.88
# Epoch   700, train loss 0.005709, train error 0.00,  test loss 8.019233, test error 55.88
# Epoch   800, train loss 0.004449, train error 0.00,  test loss 8.397616, test error 55.70
# Epoch   900, train loss 0.003550, train error 0.00,  test loss 8.711784, test error 55.78
# Training model with  55 hidden variables
# Epoch     0, train loss 2.028801, train error 75.35,  test loss 1.984450, test error 75.05
# Epoch   100, train loss 0.603419, train error 17.72,  test loss 1.665002, test error 50.22
# Epoch   200, train loss 0.184509, train error 3.78,  test loss 3.097119, test error 53.78
# Epoch   300, train loss 0.033322, train error 0.00,  test loss 4.805258, test error 54.75
# Epoch   400, train loss 0.013104, train error 0.00,  test loss 5.785885, test error 54.88
# Epoch   500, train loss 0.007909, train error 0.00,  test loss 6.397940, test error 55.05
# Epoch   600, train loss 0.005444, train error 0.00,  test loss 6.840150, test error 55.15
# Epoch   700, train loss 0.004112, train error 0.00,  test loss 7.179377, test error 55.10
# Epoch   800, train loss 0.003277, train error 0.00,  test loss 7.465581, test error 55.20
# Epoch   900, train loss 0.002687, train error 0.00,  test loss 7.706984, test error 55.10
# Training model with  60 hidden variables
# Epoch     0, train loss 2.092814, train error 77.40,  test loss 2.060063, test error 78.05
# Epoch   100, train loss 0.517428, train error 14.28,  test loss 1.799665, test error 52.55
# Epoch   200, train loss 0.095178, train error 0.70,  test loss 3.462350, test error 54.25
# Epoch   300, train loss 0.019992, train error 0.00,  test loss 4.816962, test error 54.45
# Epoch   400, train loss 0.009795, train error 0.00,  test loss 5.532804, test error 54.72
# Epoch   500, train loss 0.006183, train error 0.00,  test loss 5.995040, test error 54.55
# Epoch   600, train loss 0.004418, train error 0.00,  test loss 6.342216, test error 54.83
# Epoch   700, train loss 0.003408, train error 0.00,  test loss 6.620903, test error 54.85
# Epoch   800, train loss 0.002741, train error 0.00,  test loss 6.844969, test error 54.72
# Epoch   900, train loss 0.002263, train error 0.00,  test loss 7.041295, test error 54.85
# Training model with  70 hidden variables
# Epoch     0, train loss 2.024220, train error 75.72,  test loss 1.955417, test error 75.55
# Epoch   100, train loss 0.332897, train error 7.45,  test loss 1.969985, test error 52.58
# Epoch   200, train loss 0.029675, train error 0.00,  test loss 3.664841, test error 54.75
# Epoch   300, train loss 0.010410, train error 0.00,  test loss 4.431695, test error 54.55
# Epoch   400, train loss 0.005949, train error 0.00,  test loss 4.870910, test error 54.65
# Epoch   500, train loss 0.003996, train error 0.00,  test loss 5.179993, test error 54.60
# Epoch   600, train loss 0.002963, train error 0.00,  test loss 5.414570, test error 54.65
# Epoch   700, train loss 0.002333, train error 0.00,  test loss 5.601019, test error 54.65
# Epoch   800, train loss 0.001909, train error 0.00,  test loss 5.763769, test error 54.88
# Epoch   900, train loss 0.001605, train error 0.00,  test loss 5.900375, test error 54.97
# Training model with  80 hidden variables
# Epoch     0, train loss 2.005037, train error 74.45,  test loss 1.952905, test error 74.15
# Epoch   100, train loss 0.245912, train error 4.80,  test loss 1.970205, test error 51.62
# Epoch   200, train loss 0.022236, train error 0.00,  test loss 3.243597, test error 51.80
# Epoch   300, train loss 0.008488, train error 0.00,  test loss 3.784603, test error 51.80
# Epoch   400, train loss 0.004969, train error 0.00,  test loss 4.108958, test error 51.90
# Epoch   500, train loss 0.003406, train error 0.00,  test loss 4.344988, test error 52.10
# Epoch   600, train loss 0.002551, train error 0.00,  test loss 4.523112, test error 52.15
# Epoch   700, train loss 0.002020, train error 0.00,  test loss 4.670604, test error 52.17
# Epoch   800, train loss 0.001661, train error 0.00,  test loss 4.793744, test error 52.10
# Epoch   900, train loss 0.001403, train error 0.00,  test loss 4.901303, test error 52.20
# Training model with  90 hidden variables
# Epoch     0, train loss 2.005934, train error 74.60,  test loss 1.927371, test error 74.45
# Epoch   100, train loss 0.167564, train error 2.10,  test loss 2.171741, test error 51.92
# Epoch   200, train loss 0.015191, train error 0.00,  test loss 3.244263, test error 52.42
# Epoch   300, train loss 0.006597, train error 0.00,  test loss 3.683993, test error 52.78
# Epoch   400, train loss 0.004009, train error 0.00,  test loss 3.955244, test error 52.83
# Epoch   500, train loss 0.002814, train error 0.00,  test loss 4.146619, test error 52.72
# Epoch   600, train loss 0.002136, train error 0.00,  test loss 4.297987, test error 52.67
# Epoch   700, train loss 0.001707, train error 0.00,  test loss 4.419888, test error 52.65
# Epoch   800, train loss 0.001412, train error 0.00,  test loss 4.524158, test error 52.70
# Epoch   900, train loss 0.001199, train error 0.00,  test loss 4.613337, test error 52.62
# Training model with 100 hidden variables
# Epoch     0, train loss 1.980440, train error 72.68,  test loss 1.919118, test error 73.88
# Epoch   100, train loss 0.090056, train error 0.12,  test loss 2.264239, test error 52.05
# Epoch   200, train loss 0.012277, train error 0.00,  test loss 3.149371, test error 52.42
# Epoch   300, train loss 0.005667, train error 0.00,  test loss 3.519943, test error 52.47
# Epoch   400, train loss 0.003536, train error 0.00,  test loss 3.758865, test error 52.58
# Epoch   500, train loss 0.002520, train error 0.00,  test loss 3.930236, test error 52.55
# Epoch   600, train loss 0.001931, train error 0.00,  test loss 4.065256, test error 52.58
# Epoch   700, train loss 0.001552, train error 0.00,  test loss 4.175410, test error 52.60
# Epoch   800, train loss 0.001291, train error 0.00,  test loss 4.268042, test error 52.55
# Epoch   900, train loss 0.001100, train error 0.00,  test loss 4.350450, test error 52.40
# Training model with 120 hidden variables
# Epoch     0, train loss 1.985147, train error 73.18,  test loss 1.927505, test error 74.18
# Epoch   100, train loss 0.049304, train error 0.00,  test loss 2.284418, test error 51.30
# Epoch   200, train loss 0.009550, train error 0.00,  test loss 2.918939, test error 51.42
# Epoch   300, train loss 0.004744, train error 0.00,  test loss 3.207075, test error 51.60
# Epoch   400, train loss 0.003040, train error 0.00,  test loss 3.395000, test error 51.58
# Epoch   500, train loss 0.002195, train error 0.00,  test loss 3.533041, test error 51.70
# Epoch   600, train loss 0.001697, train error 0.00,  test loss 3.643930, test error 51.60
# Epoch   700, train loss 0.001371, train error 0.00,  test loss 3.734073, test error 51.62
# Epoch   800, train loss 0.001144, train error 0.00,  test loss 3.811745, test error 51.50
# Epoch   900, train loss 0.000978, train error 0.00,  test loss 3.879337, test error 51.45
# Training model with 140 hidden variables
# Epoch     0, train loss 1.948037, train error 71.43,  test loss 1.877316, test error 71.55
# Epoch   100, train loss 0.038616, train error 0.00,  test loss 2.138997, test error 49.60
# Epoch   200, train loss 0.008283, train error 0.00,  test loss 2.628718, test error 49.25
# Epoch   300, train loss 0.004229, train error 0.00,  test loss 2.858939, test error 49.40
# Epoch   400, train loss 0.002745, train error 0.00,  test loss 3.014586, test error 49.58
# Epoch   500, train loss 0.001992, train error 0.00,  test loss 3.127059, test error 49.58
# Epoch   600, train loss 0.001548, train error 0.00,  test loss 3.218321, test error 49.53
# Epoch   700, train loss 0.001256, train error 0.00,  test loss 3.294055, test error 49.47
# Epoch   800, train loss 0.001051, train error 0.00,  test loss 3.358193, test error 49.45
# Epoch   900, train loss 0.000901, train error 0.00,  test loss 3.414909, test error 49.50
# Training model with 160 hidden variables
# Epoch     0, train loss 1.934317, train error 71.95,  test loss 1.838730, test error 72.12
# Epoch   100, train loss 0.027745, train error 0.00,  test loss 2.138802, test error 50.03
# Epoch   200, train loss 0.007095, train error 0.00,  test loss 2.550537, test error 49.90
# Epoch   300, train loss 0.003747, train error 0.00,  test loss 2.750071, test error 49.65
# Epoch   400, train loss 0.002465, train error 0.00,  test loss 2.883915, test error 49.65
# Epoch   500, train loss 0.001805, train error 0.00,  test loss 2.984140, test error 49.67
# Epoch   600, train loss 0.001411, train error 0.00,  test loss 3.063410, test error 49.67
# Epoch   700, train loss 0.001149, train error 0.00,  test loss 3.129823, test error 49.80
# Epoch   800, train loss 0.000965, train error 0.00,  test loss 3.186798, test error 49.80
# Epoch   900, train loss 0.000828, train error 0.00,  test loss 3.236224, test error 49.80
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926617, train error 71.20,  test loss 1.832364, test error 70.97
# Epoch   100, train loss 0.024975, train error 0.00,  test loss 2.025586, test error 47.62
# Epoch   200, train loss 0.006676, train error 0.00,  test loss 2.376777, test error 47.80
# Epoch   300, train loss 0.003553, train error 0.00,  test loss 2.552034, test error 47.72
# Epoch   400, train loss 0.002354, train error 0.00,  test loss 2.672453, test error 47.65
# Epoch   500, train loss 0.001729, train error 0.00,  test loss 2.762252, test error 47.58
# Epoch   600, train loss 0.001353, train error 0.00,  test loss 2.833313, test error 47.58
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.892519, test error 47.53
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 2.943523, test error 47.50
# Epoch   900, train loss 0.000798, train error 0.00,  test loss 2.987763, test error 47.45
# Training model with 200 hidden variables
# Epoch     0, train loss 1.925781, train error 71.03,  test loss 1.858254, test error 72.18
# Epoch   100, train loss 0.021771, train error 0.00,  test loss 2.029165, test error 48.83
# Epoch   200, train loss 0.006208, train error 0.00,  test loss 2.334929, test error 48.65
# Epoch   300, train loss 0.003362, train error 0.00,  test loss 2.496961, test error 48.65
# Epoch   400, train loss 0.002243, train error 0.00,  test loss 2.604712, test error 48.65
# Epoch   500, train loss 0.001656, train error 0.00,  test loss 2.686406, test error 48.65
# Epoch   600, train loss 0.001301, train error 0.00,  test loss 2.752320, test error 48.65
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.806300, test error 48.62
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.853364, test error 48.58
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.894853, test error 48.42
# Training model with 250 hidden variables
# Epoch     0, train loss 1.903595, train error 69.10,  test loss 1.839098, test error 71.25
# Epoch   100, train loss 0.016986, train error 0.00,  test loss 1.946747, test error 47.50
# Epoch   200, train loss 0.005314, train error 0.00,  test loss 2.204609, test error 47.38
# Epoch   300, train loss 0.002961, train error 0.00,  test loss 2.342282, test error 47.42
# Epoch   400, train loss 0.002000, train error 0.00,  test loss 2.436789, test error 47.58
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.506782, test error 47.47
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.564085, test error 47.42
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.612458, test error 47.45
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.653530, test error 47.40
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.690038, test error 47.33
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877835, train error 67.70,  test loss 1.803514, test error 70.57
# Epoch   100, train loss 0.014487, train error 0.00,  test loss 1.858280, test error 46.40
# Epoch   200, train loss 0.004841, train error 0.00,  test loss 2.078096, test error 46.40
# Epoch   300, train loss 0.002740, train error 0.00,  test loss 2.197074, test error 46.35
# Epoch   400, train loss 0.001865, train error 0.00,  test loss 2.279386, test error 46.17
# Epoch   500, train loss 0.001396, train error 0.00,  test loss 2.342068, test error 46.15
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.392612, test error 46.08
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.435366, test error 46.00
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.471706, test error 45.97
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.503725, test error 45.92
# Training model with 400 hidden variables
# Epoch     0, train loss 1.862393, train error 68.18,  test loss 1.787977, test error 68.57
# Epoch   100, train loss 0.011893, train error 0.00,  test loss 1.738103, test error 45.17
# Epoch   200, train loss 0.004229, train error 0.00,  test loss 1.916268, test error 45.40
# Epoch   300, train loss 0.002442, train error 0.00,  test loss 2.014117, test error 45.58
# Epoch   400, train loss 0.001680, train error 0.00,  test loss 2.081941, test error 45.55
# Epoch   500, train loss 0.001265, train error 0.00,  test loss 2.134517, test error 45.47
# Epoch   600, train loss 0.001006, train error 0.00,  test loss 2.176733, test error 45.55
# Epoch   700, train loss 0.000831, train error 0.00,  test loss 2.211796, test error 45.53
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.242871, test error 45.47
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.269994, test error 45.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
